# %% [markdown]
# <a href="https://colab.research.google.com/github/santhosh1982/Youtube-Pytorch-Tutorial/blob/main/Tutorial_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
tensor_a = torch.tensor([1,2,3,4,5])
tensor_b = torch.tensor([6,7,8,9,10])

# %%
tensor_a - tensor_b
# Out:
# tensor([-5, -5, -5, -5, -5])

# %%
tensor_a + tensor_b
# Out:
# tensor([ 7,  9, 11, 13, 15])

# %%
m = torch.mul(tensor_a,tensor_b)
m
# Out:
# tensor([ 6, 14, 24, 36, 50])

# %%
tensor_a * tensor_b
# Out:
# tensor([ 6, 14, 24, 36, 50])

# %%
tensor_a / tensor_b
# Out:
# tensor([0.1667, 0.2857, 0.3750, 0.4444, 0.5000])

# %%
torch.div(tensor_a, tensor_b)
# Out:
# tensor([0.1667, 0.2857, 0.3750, 0.4444, 0.5000])

# %%
torch.remainder(tensor_b, tensor_a)
# Out:
# tensor([0, 1, 2, 1, 0])

# %%
torch.pow(tensor_a, tensor_b)
# Out:
# tensor([      1,     128,    6561,  262144, 9765625])

# %%
tensor_a.add(tensor_b)
# Out:
# tensor([ 7,  9, 11, 13, 15])

# %%
tensor_a = tensor_a + tensor_b
tensor_a
# Out:
# tensor([19, 23, 27, 31, 35])
