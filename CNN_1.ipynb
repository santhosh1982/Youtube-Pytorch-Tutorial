# %% [markdown]
# <a href="https://colab.research.google.com/github/santhosh1982/Youtube-Pytorch-Tutorial/blob/main/CNN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid

import numpy as np
import pandas as pd

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# (images, h, w, colors)
transform = transforms.ToTensor()

# %%
# Train Data

train_data = datasets.MNIST(root='/cnn_data', train=True, download=True, transform=transform)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 480kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.45MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.23MB/s]

# %%
test_data = datasets.MNIST(root='/cnn_data', train=False, download=True, transform=transform)

# %%
train_data
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /cnn_data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
test_data
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: /cnn_data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
pwd
# Out:
# '/content'

# %%
cd ../
# Out:
# /

# %%
cd cnn_data
# Out:
# /cnn_data

# %%
ls
# Out:
# MNIST/

# %%
cd ../
# Out:
# /

# %%
ls
# Out:
# bin@                        home/    NGC-DL-CONTAINER-LICENSE  srv/
# boot/                       kaggle/  opt/                      sys/
# cnn_data/                   lib@     proc/                     tmp/
# content/                    lib32@   python-apt/               tools/
# cuda-keyring_1.1-1_all.deb  lib64@   python-apt.tar.xz*        usr/
# datalab/                    libx32@  root/                     var/
# dev/                        media/   run/
# etc/                        mnt/     sbin@

# %%
test_data
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: /cnn_data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
# batch_size 10

train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

# %%
conv1 = nn.Conv2d(1, 6, 3, 1)
conv2 = nn.Conv2d(6, 16, 3, 1)
# conv3 = nn.Conv2d()

# %%
for i, (X_train, y_train) in enumerate(train_loader):
    print(i, X_train.shape, y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1000 torch.Size([10, 1, 28, 28]) tensor([5, 7, 9, 5, 3, 2, 7, 2, 1, 5])
# 1001 torch.Size([10, 1, 28, 28]) tensor([7, 9, 2, 2, 3, 6, 6, 6, 8, 9])
# 1002 torch.Size([10, 1, 28, 28]) tensor([5, 0, 8, 7, 8, 7, 4, 9, 9, 5])
# 1003 torch.Size([10, 1, 28, 28]) tensor([3, 2, 3, 5, 4, 5, 0, 2, 4, 2])
# 1004 torch.Size([10, 1, 28, 28]) tensor([1, 6, 5, 0, 8, 8, 1, 9, 4, 4])
# 1005 torch.Size([10, 1, 28, 28]) tensor([8, 9, 9, 5, 2, 1, 6, 1, 0, 4])
# 1006 torch.Size([10, 1, 28, 28]) tensor([4, 0, 1, 4, 5, 1, 6, 8, 7, 1])
# 1007 torch.Size([10, 1, 28, 28]) tensor([6, 0, 1, 2, 0, 1, 5, 0, 6, 1])
# 1008 torch.Size([10, 1, 28, 28]) tensor([6, 7, 4, 6, 6, 8, 2, 1, 8, 1])
# 1009 torch.Size([10, 1, 28, 28]) tensor([3, 2, 0, 3, 1, 9, 3, 4, 0, 4])
# 1010 torch.Size([10, 1, 28, 28]) tensor([3, 9, 2, 8, 5, 8, 8, 0, 4, 8])
# 1011 torch.Size([10, 1, 28, 28]) tensor([5, 8, 6, 0, 2, 5, 7, 8, 8, 8])
# ...

# %%
X_train.shape
# Out:
# torch.Size([10, 1, 28, 28])

# %%
x = X_train.view(10,1,28,28)

# %%
x = F.relu(conv1(x))
x.shape
# Out:
# torch.Size([10, 6, 26, 26])

# %%
x = F.max_pool2d(x, 2, 2) # kernel of 2 and stride of 2

# %%
x.shape
# Out:
# torch.Size([10, 6, 13, 13])

# %%
x = F.relu(conv2(x))
x.shape
# Out:
# torch.Size([10, 16, 11, 11])

# %%
x = F.max_pool2d(x, 2, 2)

# %%
x.shape
# Out:
# torch.Size([10, 16, 5, 5])

# %%
((28-2)/2 - 2)/2
# Out:
# 5.5
